# %%
from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_checker import check_env
import gym
import numpy as np
from RL import helpers
from Hack import load
# %matplotlib qt5

# %%
# define the data
epex = load.epex().load()
price_array = epex['apx_da_hourly'].values

# define environment
#! window_size is sort of a free parameter
max_time = 30769 
env = helpers.energy_price_env(price_array, max_time=max_time, window_size=24*2)

check_env(env, warn=True)
# Out:
# C:\Users\mgmf4\anaconda3\envs\ml\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
model1= PPO(MlpPolicy, env, verbose=1, seed = 0) # default
print("BEFORE")
#mean_reward_before_train = helpers.evaluate(model1, num_episodes=10, index = epex.index)
# Train the agent for 10000 steps
model1.learn(total_timesteps=50000)
model1.save("../model_dir/trained_model1")
# Trained Agent, after training
periods = 48*7
new_env =  DummyVecEnv([lambda: helpers.energy_price_env(price_array, start_time=max_time, max_time = periods)])
print("AFTER")
mean_reward_after_train = helpers.evaluate(model1, new_env=new_env, num_episodes=10, index=epex.index)
# load model using loaded_model = PPO.load("path_to_model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# BEFORE
# -----------------------------
# | time/              |      |
# |    fps             | 1683 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1056        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011748658 |
# |    clip_fraction        | 0.0131      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00575     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 22.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 932          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0024896148 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -7.27e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.77         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -1.83e-05    |
# |    value_loss           | 18           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009236362 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000463   |
# |    value_loss           | 27.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008545354 |
# |    clip_fraction        | 0.00728     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.000366   |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012768054 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 24          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011734971 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00356    |
# |    value_loss           | 33.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 785          |
# |    iterations           | 8            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0054150256 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000169    |
# |    value_loss           | 37.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002555089 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.000265   |
# |    value_loss           | 42.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 780        |
# |    iterations           | 10         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00249827 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.5       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -1.97e-05  |
# |    value_loss           | 32.3       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 766          |
# |    iterations           | 11           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0058976957 |
# |    clip_fraction        | 0.00112      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.03         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000659    |
# |    value_loss           | 19.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 12           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0009934851 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000104    |
# |    value_loss           | 22.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 13          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007392725 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 14          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014460206 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 66.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013528929 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0062     |
# |    value_loss           | 96.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006326461 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 146         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000128   |
# |    value_loss           | 175         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 17          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005067383 |
# |    clip_fraction        | 0.00728     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.00866     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 13.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 18          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005731769 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 8.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.08e+04     |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 19           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0032623145 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.39         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -6.83e-05    |
# |    value_loss           | 13.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 20          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017208593 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.64        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0056     |
# |    value_loss           | 16.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.08e+04     |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 778          |
# |    iterations           | 21           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0019459517 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -9.29e-05    |
# |    value_loss           | 23.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 781         |
# |    iterations           | 22          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009071469 |
# |    clip_fraction        | 0.00205     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0012     |
# |    value_loss           | 27.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 23          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004837094 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.38        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00336    |
# |    value_loss           | 28.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.08e+04    |
# |    ep_rew_mean          | -360        |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 24          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012748398 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16          |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 27.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.08e+04     |
# |    ep_rew_mean          | -360         |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 25           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0041268687 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.56         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000763    |
# |    value_loss           | 18.3         |
# ------------------------------------------
# C:\Users\mgmf4\anaconda3\envs\ml\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# AFTER
# Mean reward: 111.61526 +/- 166.67862 	 Num episodes: 10

# %%
model2= PPO(MlpPolicy, env, learning_rate = 0.02, verbose=1, seed = 0) # default
print("BEFORE")
#mean_reward_before_train = helpers.evaluate(model2, num_episodes=10, index = epex.index)
# Train the agent for 10000 steps
model2.learn(total_timesteps=50000)
model2.save("../model_dir/trained_model2")
# Trained Agent, after training
periods = 48*7
new_env =  DummyVecEnv([lambda: helpers.energy_price_env(price_array, start_time=max_time, max_time = periods)])
print("AFTER")
mean_reward_after_train = helpers.evaluate(model2, new_env=new_env, num_episodes=10, index=epex.index)
# load model using loaded_model = PPO.load("path_to_model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# BEFORE
# -----------------------------
# | time/              |      |
# |    fps             | 1557 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1044       |
# |    iterations           | 2          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.88744915 |
# |    clip_fraction        | 0.64       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.965     |
# |    explained_variance   | 0.00575    |
# |    learning_rate        | 0.02       |
# |    loss                 | 14.3       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.0855     |
# |    value_loss           | 23         |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 931       |
# |    iterations           | 3         |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.4563666 |
# |    clip_fraction        | 0.14      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.025    |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.777     |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.04      |
# |    value_loss           | 2.53      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 863        |
# |    iterations           | 4          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.20492098 |
# |    clip_fraction        | 0.02       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0126    |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.02       |
# |    loss                 | 0.00631    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.00305    |
# |    value_loss           | 0.000883   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 834       |
# |    iterations           | 5         |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.26e-05 |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.00585   |
# |    n_updates            | 40        |
# |    policy_gradient_loss | 8.16e-06  |
# |    value_loss           | 0.0123    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 6         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.00303   |
# |    n_updates            | 50        |
# |    policy_gradient_loss | 2.55e-05  |
# |    value_loss           | 0.0104    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 806       |
# |    iterations           | 7         |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.000119  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | 0.000237  |
# |    value_loss           | 0.000533  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 805       |
# |    iterations           | 8         |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.00521   |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.000184 |
# |    value_loss           | 0.00893   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 806       |
# |    iterations           | 9         |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.000124  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | 3.75e-05  |
# |    value_loss           | 0.000382  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 808       |
# |    iterations           | 10        |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 4.75e-06  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -9.48e-07 |
# |    value_loss           | 0.000893  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 808       |
# |    iterations           | 11        |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.000488  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | 0.00119   |
# |    value_loss           | 0.00341   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 813       |
# |    iterations           | 12        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 8.14e-06  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -2.66e-05 |
# |    value_loss           | 0.0339    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 13        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.00439   |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -4.4e-05  |
# |    value_loss           | 0.0119    |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 14        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | -6.65e-07 |
# |    n_updates            | 130       |
# |    policy_gradient_loss | 4.08e-05  |
# |    value_loss           | 0.00247   |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 816       |
# |    iterations           | 15        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.02      |
# |    loss                 | 2.08e-05  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | 3.25e-05  |
# |    value_loss           | 0.00127   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 816       |
# |    iterations           | 16        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 7.24e-05  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | 0.000282  |
# |    value_loss           | 0.00693   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 816       |
# |    iterations           | 17        |
# |    time_elapsed         | 42        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0.837     |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.0205    |
# |    n_updates            | 160       |
# |    policy_gradient_loss | 1.28e-09  |
# |    value_loss           | 0.126     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 816       |
# |    iterations           | 18        |
# |    time_elapsed         | 45        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0.731     |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.0047    |
# |    n_updates            | 170       |
# |    policy_gradient_loss | 1.4e-08   |
# |    value_loss           | 0.0147    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 815       |
# |    iterations           | 19        |
# |    time_elapsed         | 47        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.02      |
# |    loss                 | 4.19e-06  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | 4.02e-06  |
# |    value_loss           | 0.00779   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 20        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | -2.02e-06 |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -1.81e-05 |
# |    value_loss           | 7.52e-09  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 21        |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.000255  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 1.67e-05  |
# |    value_loss           | 0.00179   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 22        |
# |    time_elapsed         | 55        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.0614    |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.000172 |
# |    value_loss           | 0.112     |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 813       |
# |    iterations           | 23        |
# |    time_elapsed         | 57        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 0.00218   |
# |    n_updates            | 220       |
# |    policy_gradient_loss | 0.000775  |
# |    value_loss           | 0.00887   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 24        |
# |    time_elapsed         | 60        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.02      |
# |    loss                 | 8.37e-07  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -6.61e-05 |
# |    value_loss           | 0.000749  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -55.2     |
# | time/                   |           |
# |    fps                  | 814       |
# |    iterations           | 25        |
# |    time_elapsed         | 62        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.44e-06 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.02      |
# |    loss                 | 6.15e-06  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | 9.32e-06  |
# |    value_loss           | 0.00185   |
# ---------------------------------------
# C:\Users\mgmf4\anaconda3\envs\ml\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# AFTER
# Mean reward: 0.0 +/- 0.0 	 Num episodes: 10

# %%
model3 = PPO(MlpPolicy, env, learning_rate = 0.1, verbose=1, seed = 0) # default
print("BEFORE")
#mean_reward_before_train = helpers.evaluate(model3, num_episodes=10, index = epex.index)
# Train the agent for 10000 steps
model3.learn(total_timesteps=50000)
model3.save("../model_dir/trained_model3")
# Trained Agent, after training
periods = 48*7
new_env =  DummyVecEnv([lambda: helpers.energy_price_env(price_array, start_time=max_time, max_time = periods)])
print("AFTER")
mean_reward_after_train = helpers.evaluate(model3, new_env=new_env, num_episodes=10, index=epex.index)
# load model using loaded_model = PPO.load("path_to_model")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# BEFORE
# -----------------------------
# | time/              |      |
# |    fps             | 1669 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1081      |
# |    iterations           | 2         |
# |    time_elapsed         | 3         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 31.613228 |
# |    clip_fraction        | 0.997     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00912  |
# |    explained_variance   | 0.00575   |
# |    learning_rate        | 0.1       |
# |    loss                 | 13.9      |
# |    n_updates            | 10        |
# |    policy_gradient_loss | 0.428     |
# |    value_loss           | 25.6      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 968       |
# |    iterations           | 3         |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 1.41      |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.000423 |
# |    value_loss           | 1.33      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 910       |
# |    iterations           | 4         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.485     |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -4.93e-05 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 887       |
# |    iterations           | 5         |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.495     |
# |    n_updates            | 40        |
# |    policy_gradient_loss | 0.000221  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 872       |
# |    iterations           | 6         |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.487     |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -3.12e-05 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 861       |
# |    iterations           | 7         |
# |    time_elapsed         | 16        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -9.61e-06 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 854       |
# |    iterations           | 8         |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.487     |
# |    n_updates            | 70        |
# |    policy_gradient_loss | 3.97e-05  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 846       |
# |    iterations           | 9         |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.481     |
# |    n_updates            | 80        |
# |    policy_gradient_loss | 1.2e-05   |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 840       |
# |    iterations           | 10        |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -3.79e-05 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 830       |
# |    iterations           | 11        |
# |    time_elapsed         | 27        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -0.00164  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 817       |
# |    iterations           | 12        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.487     |
# |    n_updates            | 110       |
# |    policy_gradient_loss | 2.87e-05  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 811       |
# |    iterations           | 13        |
# |    time_elapsed         | 32        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.484     |
# |    n_updates            | 120       |
# |    policy_gradient_loss | 2.39e-05  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 811       |
# |    iterations           | 14        |
# |    time_elapsed         | 35        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 130       |
# |    policy_gradient_loss | 5.09e-05  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 810       |
# |    iterations           | 15        |
# |    time_elapsed         | 37        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.482     |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -3.26e-05 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 808       |
# |    iterations           | 16        |
# |    time_elapsed         | 40        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.485     |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -0.000591 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 808       |
# |    iterations           | 17        |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 4.17e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.485     |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -2.52e-06 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 807       |
# |    iterations           | 18        |
# |    time_elapsed         | 45        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -9.8e-05  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.487     |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -8.52e-05 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 804       |
# |    iterations           | 19        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -3.62e-07 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 803       |
# |    iterations           | 20        |
# |    time_elapsed         | 50        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.487     |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -0.000179 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 802       |
# |    iterations           | 21        |
# |    time_elapsed         | 53        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.487     |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 5.32e-05  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 801       |
# |    iterations           | 22        |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.00114   |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 800       |
# |    iterations           | 23        |
# |    time_elapsed         | 58        |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -0.00123  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 800       |
# |    iterations           | 24        |
# |    time_elapsed         | 61        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.486     |
# |    n_updates            | 230       |
# |    policy_gradient_loss | 1.79e-05  |
# |    value_loss           | 1.24      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.08e+04  |
# |    ep_rew_mean          | -59.7     |
# | time/                   |           |
# |    fps                  | 799       |
# |    iterations           | 25        |
# |    time_elapsed         | 64        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.32e-16 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.1       |
# |    loss                 | 0.485     |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -9.41e-06 |
# |    value_loss           | 1.24      |
# ---------------------------------------
# C:\Users\mgmf4\anaconda3\envs\ml\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# AFTER
# Mean reward: 0.0 +/- 0.0 	 Num episodes: 10
